# %%
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img.shape
# Out:
# (100, 100, 3)

# %%
import glob
cv_img = []
adr = []
for img in glob.glob("E:/CodeFunDo/TCHP_Extracted/*.png"):
    im = cv.imread(img)
    im = cv.cvtColor(im, cv.COLOR_BGR2RGB)
    #print(str(img))
    adr.append(str(img))
    cv_img.append(im)

# %%
adr[0][27:]
# Out:
# '20100201.png'

# %%
plt.imshow(cv_img[0])

# %%
i = 0
path = "E:\CodeFunDo\TCHP_cropped\ " 
for img in cv_img:
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    img = img[79:209,184:335]
    cv.imwrite(path+adr[i][28:],img)
    i = i+1
    #plt.imshow(img)

# %%
cv.imwrite('C:/Users/SHREEKANTH/Desktop/cfd_img/ab.png',cv_img[1])
# Out:
# True

# %%
adr[0][27:]
# Out:
# '\\20120101tchp.png'

# %%
import numpy as np
im = cv.imread(r'C:\Users\USER\Desktop\20100201.png')
#im = cv.cvtColor(im, cv.COLOR_BGR2RGB)
#img = im[206:276,248:327]
#plt.imshow(img)
a = np.array(im)
plt.imshow(im)

# %%
im.shape
# Out:
# (538, 1076, 3)

# %%
im = cv.imread(r'C:/Users/SHREEKANTH/Desktop/cfd_img/tchp1.png')
im = cv.cvtColor(im, cv.COLOR_BGR2RGB)
img = im[79:209,184:335]
plt.imshow(img)

# %%
im = cv.imread(r'C:/Users/SHREEKANTH/Desktop/cfd_img/WF1.png')
im = cv.cvtColor(im, cv.COLOR_BGR2RGB)
#img = im[79:209,184:335]
#ret,thresh = cv.threshold(im,0,255)
plt.imshow(im)

# %%
import numpy as np
a = np.array(im)
img = im [145:146,210:211]
plt.imshow(img)
print(a[145][210])
c = 0
for i in range(0,im.shape[0]):
    for j in range(0,im.shape[1]):
        if all(a[i][j]==0):
            im[i][j]=[255,255,255]
print(c)
# Out:
# [0 0 0]
# 0

# %%
im.shape
all(a[1][1]==255)
# Out:
# True

# %%
plt.imshow(im)
cv.imwrite('removed.png',im)
# Out:
# True
